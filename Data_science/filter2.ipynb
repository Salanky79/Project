# %%
import pandas as pd
import numpy as np

df_laptops = pd.read_csv('laptop_price.csv', encoding='latin1')

# %%
# set the cheapest laptop of each company first and the most expensive last
df_laptops = df_laptops.sort_values(['Company', 'Price_euros'])
df_laptops
# Out:
#       laptop_ID Company                           Product   TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST   Notebook    15.6
# 1102       1117    Acer                     Chromebook 15   Notebook    15.6
# 695         703    Acer                 TravelMate B117-M    Netbook    11.6
# 1198       1216    Acer                          Aspire 3   Notebook    15.6
# ...         ...     ...                               ...        ...     ...
# 191         195    Vero     K147 (N3350/4GB/32GB/FHD/W10)   Notebook    14.0
# 877         888  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 192         196  Xiaomi                       Mi Notebook  Ultrabook    13.3
# 184         188  Xiaomi                       Mi Notebook   Notebook    15.6
# 514         521  Xiaomi                       Mi Notebook   Notebook    15.6
#
# ...

# %%
# chi in ra cai loai re nhat cua moi cong ty
df_laptops.drop_duplicates(['Company'], keep='first', inplace=True, ignore_index=True)
df_laptops
# Out:
# C:\Users\AD\AppData\Local\Temp\ipykernel_2500\845018083.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_laptops.drop_duplicates(['Company'], keep='first', inplace=True, ignore_index=True)
#     laptop_ID    Company                           Product   TypeName  Inches  \
# 0        1233       Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6
# 1           2      Apple                       Macbook Air  Ultrabook    13.3
# 2          21       Asus                   Vivobook E200HA    Netbook    11.6
# 3          31      Chuwi                     LapBook 15.6"   Notebook    15.6
# 4         346       Dell                     Inspiron 3552   Notebook    15.6
# 5         997    Fujitsu                     LifeBook A556   Notebook    15.6
# ...

# %%
# chi in ra cai loai dat nhat cua moi cong ty
duplicated_first = df_laptops.duplicated('Company', keep='last')
df_laptops[~duplicated_first][['Company', 'Price_euros']] # ~ == not
# Out:
#         Company  Price_euros
# 1215       Acer       174.00
# 1         Apple       898.94
# 20         Asus       191.90
# 30        Chuwi       244.99
# 340        Dell       274.90
# 983     Fujitsu       649.00
# 472      Google      1275.00
# 1268         HP       209.00
# 170      Huawei      1349.00
# 909          LG      1899.00
# 1272     Lenovo       229.00
# 1169        MSI       839.00
# 626    Mediacom       239.00
# 457   Microsoft       989.00
# 1117      Razer      1029.00
# 430     Samsung       269.00
# 159     Toshiba       447.00
# 1120       Vero       196.00
# 877      Xiaomi       935.00

# %%
# .drop_duplicated() (~ duplicated)
