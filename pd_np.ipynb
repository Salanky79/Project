# %%
import pandas as pd

# reading 1 csv file from the web

df_premier25 =  pd.read_csv('https://www.football-data.co.uk/mmz4281/2526/E0.csv')

# %%
#showing DataFrame

df_premier25

# %%
df_premier25.rename(columns= {'FTHG': 'home_goals', 'FTAG': 'away_goals'}, inplace= True)
df_premier25
# Out:
#    Div        Date   Time        HomeTeam        AwayTeam  home_goals  \
# 0   E0  15/08/2025  20:00       Liverpool     Bournemouth           4
# 1   E0  16/08/2025  12:30     Aston Villa       Newcastle           0
# 2   E0  16/08/2025  15:00        Brighton          Fulham           1
# 3   E0  16/08/2025  15:00      Sunderland        West Ham           3
# 4   E0  16/08/2025  15:00       Tottenham         Burnley           3
# 5   E0  16/08/2025  17:30          Wolves        Man City           0
# 6   E0  17/08/2025  14:00         Chelsea  Crystal Palace           0
# 7   E0  17/08/2025  14:00   Nott'm Forest       Brentford           3
# 8   E0  17/08/2025  16:30      Man United         Arsenal           0
# 9   E0  18/08/2025  20:00           Leeds         Everton           1
# 10  E0  22/08/2025  20:00        West Ham         Chelsea           1
# 11  E0  23/08/2025  12:30        Man City       Tottenham           0
# ...

# %%
# Link examples:

# https://www.football-data.co.uk/mmz4281/2526/E0.csv
# https://www.football-data.co.uk/mmz4281/2526/E1.csv

# root + season + league



#create a root variable
root = "https://www.football-data.co.uk/mmz4281/"

#creating list of leagues
leagues = ['E0', 'E1', 'E2', 'E3', 'EC']
frames = []
#looping through leagues, read multiple csv and append it into a list (or else it will lost the df)
for league in leagues:
    df = pd.read_csv( root + '2526/' + league + '.csv', encoding='unicode_escape')
    frames.append(df)

# %%
len(frames)
# Out:
# 5

# %%
#-------------------------Multiple seasons----------------------



root = "https://www.football-data.co.uk/mmz4281/"

#creating list of leagues
leagues = ['E0', 'E2', 'E3']
frames = []
#looping through leagues, read multiple csv and append it into a list (or else it will lost the df)
for league in leagues:
    for season in range (20,26):
        df = pd.read_csv( root + str(season) + str(season+1) + '/' + league + '.csv', encoding='unicode_escape')
        df.insert(1, 'season', season)
        frames.append(df)

# %%
len(frames)
# Out:
# 18

# %%
dict_contries = {"English Premier League": 'E0', "English League 1": 'E2', "English League 2": 'E3'}
for league in dict_contries:
    print(dict_contries[league])
# Out:
# E0
# E2
# E3

# %%
# --------------- Organize all the Data in a Dictionary ------------------
dict_historical_data = {}
dict_contries = {"English Premier League": 'E0', "English League 1": 'E2', "English League 2": 'E3'}

#creating list of leagues
#leagues = ['E0', 'E2', 'E3']

#looping through key elements
for league in dict_contries:
    frames = [] # chứa tất cả mùa của CHỈ DUY NHẤT 1 GIẢI (vd: tất cả các mùa (20-25) của Englíh league 1)
    for season in range (20,26):
        df = pd.read_csv( root + str(season) + str(season+1) + '/' + dict_contries[league] + '.csv', encoding='unicode_escape')
        df.insert(1, 'season', season)
        frames.append(df) 
    # 👉 Nối (concat) tất cả DataFrame của 1 giải lại với nhau
    df_concat = pd.concat(frames)
    # 👉 Lưu kết quả vào dictionary
    dict_historical_data[league] = df_concat

# %%
# show dataFrame inside dict_historical_data
dict_historical_data['English Premier League']
# Out:
#     Div  season        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG  \
# 0    E0      20  12/09/2020  12:30          Fulham      Arsenal     0     3
# 1    E0      20  12/09/2020  15:00  Crystal Palace  Southampton     1     0
# 2    E0      20  12/09/2020  17:30       Liverpool        Leeds     4     3
# 3    E0      20  12/09/2020  20:00        West Ham    Newcastle     0     2
# 4    E0      20  13/09/2020  14:00       West Brom    Leicester     0     3
# ..  ...     ...         ...    ...             ...          ...   ...   ...
# 55  NaN      25  27/09/2025  17:30   Nott'm Forest   Sunderland     0     1
# 56  NaN      25  27/09/2025  20:00       Tottenham       Wolves     1     1
# 57  NaN      25  28/09/2025  14:00     Aston Villa       Fulham     3     1
# 58  NaN      25  28/09/2025  16:30       Newcastle      Arsenal     1     2
# 59  NaN      25  29/09/2025  20:00         Everton     West Ham     1     1
#
# ...

# %%
for season in range(20,26):
    df = pd.read_csv(root + str(season) + str(season+1) + '/' + dict_contries[league] + '.csv', encoding='unicode_escape')
    print(season, df.columns.tolist())
# Out:
# 20 ['Div', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'B365H', 'B365D', 'B365A', 'BWH', 'BWD', 'BWA', 'IWH', 'IWD', 'IWA', 'PSH', 'PSD', 'PSA', 'WHH', 'WHD', 'WHA', 'VCH', 'VCD', 'VCA', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'B365>2.5', 'B365<2.5', 'P>2.5', 'P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'AHh', 'B365AHH', 'B365AHA', 'PAHH', 'PAHA', 'MaxAHH', 'MaxAHA', 'AvgAHH', 'AvgAHA', 'B365CH', 'B365CD', 'B365CA', 'BWCH', 'BWCD', 'BWCA', 'IWCH', 'IWCD', 'IWCA', 'PSCH', 'PSCD', 'PSCA', 'WHCH', 'WHCD', 'WHCA', 'VCCH', 'VCCD', 'VCCA', 'MaxCH', 'MaxCD', 'MaxCA', 'AvgCH', 'AvgCD', 'AvgCA', 'B365C>2.5', 'B365C<2.5', 'PC>2.5', 'PC<2.5', 'MaxC>2.5', 'MaxC<2.5', 'AvgC>2.5', 'AvgC<2.5', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH', 'MaxCAHA', 'AvgCAHH', 'AvgCAHA']
# ...
